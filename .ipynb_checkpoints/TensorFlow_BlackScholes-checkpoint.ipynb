# %% [markdown]
# ### Generate Option Price Data Set

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Black Scholes Option Pricing Formula

def BS_Call(S,K,r,T,v,d=0):
    d1 = (np.log(float(S)/K)+((r-d)+v*v/2.)*T)/(v*np.sqrt(T))
    d2 = d1-v*np.sqrt(T)
    return S*np.exp(-d*T)*ss.norm.cdf(d1)-K*np.exp(-r*T)*ss.norm.cdf(d2)

# %%
## Build pandas dataframe of prices
S = np.arange(1, 100, 1)
K = np.arange(1, 100, 1)
r = 0.05
T = np.arange(0.05, 1, 0.1)
V = np.arange(0.05, 0.5, 0.04)

# Number of option prices = life begins at a million examples
no_of_options = len(S)*len(K)*len(T)*len(V)
no_of_options
# Out:
# 1176120

# %%
prices = np.empty([no_of_options,6], dtype=float)

# %%
# %%time
x = 0
for s in S:
    for k in K:
        for t in T:
            for v in V:
                prices[x,:] = [s,k,t,0.05,v,BS_Call(s,k,r,t,v)]
                x+=1
# Out:
# Wall time: 2min 54s

# %%
option_df = pd.DataFrame(index = range(no_of_options), columns = 
                         ['Stock', 
                          'Strike',
                          'Time',
                          'Risk_free',
                          'Volatility',
                          'Call Price'], data = prices )

# %%
##Normalize dats

option_df['Stock'] = option_df['Stock'].div(option_df.Strike)
option_df['Strike'] = option_df['Strike'].div(option_df.Strike)
option_df['Call Price'] = option_df['Call Price'].div(option_df.Strike)

# %%
option_df.head(100)
# Out:
#     Stock  Strike  Time  Risk_free  Volatility  Call Price
# 0     1.0     1.0  0.05       0.05        0.05    0.005814
# 1     1.0     1.0  0.05       0.05        0.09    0.009329
# 2     1.0     1.0  0.05       0.05        0.13    0.012873
# 3     1.0     1.0  0.05       0.05        0.17    0.016426
# 4     1.0     1.0  0.05       0.05        0.21    0.019983
# 5     1.0     1.0  0.05       0.05        0.25    0.023542
# 6     1.0     1.0  0.05       0.05        0.29    0.027101
# 7     1.0     1.0  0.05       0.05        0.33    0.030660
# 8     1.0     1.0  0.05       0.05        0.37    0.034219
# 9     1.0     1.0  0.05       0.05        0.41    0.037778
# 10    1.0     1.0  0.05       0.05        0.45    0.041337
# 11    1.0     1.0  0.05       0.05        0.49    0.044894
# 12    1.0     1.0  0.15       0.05        0.05    0.012003
# 13    1.0     1.0  0.15       0.05        0.09    0.017909
# 14    1.0     1.0  0.15       0.05        0.13    0.023967
# 15    1.0     1.0  0.15       0.05        0.17    0.030069
# 16    1.0     1.0  0.15       0.05        0.21    0.036190
# 17    1.0     1.0  0.15       0.05        0.25    0.042319
# 18    1.0     1.0  0.15       0.05        0.29    0.048452
# 19    1.0     1.0  0.15       0.05        0.33    0.054586
# 20    1.0     1.0  0.15       0.05        0.37    0.060720
# 21    1.0     1.0  0.15       0.05        0.41    0.066852
# 22    1.0     1.0  0.15       0.05        0.45    0.072982
# 23    1.0     1.0  0.15       0.05        0.49    0.079108
# 24    1.0     1.0  0.25       0.05        0.05    0.017336
# 25    1.0     1.0  0.25       0.05        0.09    0.024734
# 26    1.0     1.0  0.25       0.05        0.13    0.032452
# 27    1.0     1.0  0.25       0.05        0.17    0.040264
# 28    1.0     1.0  0.25       0.05        0.21    0.048115
# 29    1.0     1.0  0.25       0.05        0.25    0.055984
# ..    ...     ...   ...        ...         ...         ...
# 70    1.0     1.0  0.55       0.05        0.45    0.144728
# 71    1.0     1.0  0.55       0.05        0.49    0.156189
# 72    1.0     1.0  0.65       0.05        0.05    0.036692
# 73    1.0     1.0  0.65       0.05        0.09    0.047275
# 74    1.0     1.0  0.65       0.05        0.13    0.059074
# 75    1.0     1.0  0.65       0.05        0.17    0.071253
# 76    1.0     1.0  0.65       0.05        0.21    0.083590
# 77    1.0     1.0  0.65       0.05        0.25    0.096000
# 78    1.0     1.0  0.65       0.05        0.29    0.108443
# 79    1.0     1.0  0.65       0.05        0.33    0.120896
# 80    1.0     1.0  0.65       0.05        0.37    0.133346
# 81    1.0     1.0  0.65       0.05        0.41    0.145781
# 82    1.0     1.0  0.65       0.05        0.45    0.158196
# 83    1.0     1.0  0.65       0.05        0.49    0.170583
# 84    1.0     1.0  0.75       0.05        0.05    0.041345
# 85    1.0     1.0  0.75       0.05        0.09    0.052380
# 86    1.0     1.0  0.75       0.05        0.13    0.064886
# 87    1.0     1.0  0.75       0.05        0.17    0.077859
# 88    1.0     1.0  0.75       0.05        0.21    0.091026
# 89    1.0     1.0  0.75       0.05        0.25    0.104283
# 90    1.0     1.0  0.75       0.05        0.29    0.117580
# 91    1.0     1.0  0.75       0.05        0.33    0.130890
# 92    1.0     1.0  0.75       0.05        0.37    0.144196
# 93    1.0     1.0  0.75       0.05        0.41    0.157484
# 94    1.0     1.0  0.75       0.05        0.45    0.170746
# 95    1.0     1.0  0.75       0.05        0.49    0.183975
# 96    1.0     1.0  0.85       0.05        0.05    0.045962
# 97    1.0     1.0  0.85       0.05        0.09    0.057366
# 98    1.0     1.0  0.85       0.05        0.13    0.070504
# 99    1.0     1.0  0.85       0.05        0.17    0.084198
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Build Keras Model

# %%
prices = option_df.values

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten

# %%
# Decide split for train and test set

m = 0.5
end = len(prices)
split = int(m*end)
split
# Out:
# 588060

# %%
## Define X & Y
X_train = prices[:split,:5]
y_train = prices[:split,5:6]
X_test = prices[split:end, :5]
y_test = prices[split:end,5:6]

# %%
model = Sequential()
model.add(Dense(10, input_shape=(5,), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error',
        optimizer='adam')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 10)                60
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                110
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 291
# Trainable params: 291
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# 588060/588060 [==============================] - 47s 80us/step - loss: 37.1402
# Epoch 2/10
# 588060/588060 [==============================] - 47s 80us/step - loss: 25.5520
# Epoch 3/10
# 588060/588060 [==============================] - 47s 80us/step - loss: 25.0836
# Epoch 4/10
# 588060/588060 [==============================] - 48s 82us/step - loss: 24.8961
# Epoch 5/10
# 588060/588060 [==============================] - 52s 88us/step - loss: 24.8296
# Epoch 6/10
# 588060/588060 [==============================] - 50s 86us/step - loss: 24.7849
# Epoch 7/10
# 588060/588060 [==============================] - 47s 80us/step - loss: 24.7556
# Epoch 8/10
# 588060/588060 [==============================] - 48s 82us/step - loss: 24.7264
# Epoch 9/10
# 588060/588060 [==============================] - 48s 82us/step - loss: 24.7274
# Epoch 10/10
# 588060/588060 [==============================] - 47s 80us/step - loss: 24.6590

# %%
predictions = model.predict(X_train)

# %%
for x in range(50):
    print(predictions[x], y_train[x])
# Out:
# [3.296135] [0.00581406]
# [3.316082] [0.00932863]
# [3.336029] [0.01287316]
# [3.355978] [0.01642639]
# [3.375924] [0.01998314]
# [3.395872] [0.02354151]
# [3.4158182] [0.0271006]
# [3.4357672] [0.03065993]
# [3.4557142] [0.03421916]
# [3.4756622] [0.0377781]
# [3.4956093] [0.04133657]
# [3.5155563] [0.04489443]
# [3.3335295] [0.01200258]
# [3.3534775] [0.0179086]
# [3.3734236] [0.02396661]
# [3.3933716] [0.03006926]
# [3.4133186] [0.0361901]
# [3.4332666] [0.04231931]
# [3.4532137] [0.04845226]
# [3.4731627] [0.05458638]
# [3.4931107] [0.06072007]
# [3.5130558] [0.06685219]
# [3.5330038] [0.07298188]
# [3.5529518] [0.07910846]
# [3.370925] [0.01733611]
# [3.390873] [0.02473422]
# [3.410819] [0.03245155]
# [3.430766] [0.04026384]
# [3.450714] [0.04811498]
# [3.470662] [0.055984]
# [3.4906092] [0.06386103]
# [3.5105562] [0.07174059]
# [3.5305042] [0.0796192]
# [3.5504513] [0.08749446]
# [3.5703993] [0.09536454]
# [3.5903473] [0.10322794]
# [3.4083185] [0.02236124]
# [3.4282665] [0.03085551]
# [3.4482136] [0.03986594]
# [3.4681616] [0.0490319]
# [3.4881096] [0.05826173]
# [3.5080576] [0.06752102]
# [3.5280037] [0.07679349]
# [3.5479507] [0.08607012]
# [3.5678997] [0.0953452]
# [3.5878468] [0.10461476]
# [3.6077948] [0.11387577]
# [3.6277409] [0.12312579]
# [3.445713] [0.02722568]
# [3.465662] [0.0365728]
